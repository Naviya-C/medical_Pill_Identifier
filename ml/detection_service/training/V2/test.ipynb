# %%
from ultralytics import YOLO
import torch

# %%
model = YOLO("/home/naviya-c/Desktop/Projects/pill-id-platform/ml/detection_service/inference/models/best_YOLOv11m-v1.pt")

# %%
model.predict(
    source = "/home/naviya-c/Downloads/pill.jpeg",
    imgsz = 640,
    project="/home/naviya-c/Desktop/Projects/pill-id-platform/ml/detection_service/training/V2",
    exist_ok = True,
    save = True
    )
# Out:
# image 1/1 /home/naviya-c/Downloads/pill.jpeg: 352x640 18 pills, 42.9ms
# Speed: 10.7ms preprocess, 42.9ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to /home/naviya-c/Desktop/Projects/pill-id-platform/ml/detection_service/training/V2/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pill'}
#  obb: None
#  orig_img: array([[[241, 214, 164],
#          [241, 214, 164],
#          [241, 214, 164],
#          ...,
#          [  3,  97, 226],
#          [  1,  95, 224],
#          [  3,  97, 227]],
#
#         [[241, 214, 164],
#          [241, 214, 164],
#          [241, 214, 164],
#          ...,
#          [  4,  98, 227],
#          [  1,  95, 224],
#          [  1,  95, 225]],
#
#         [[241, 214, 164],
#          [241, 214, 164],
#          [241, 214, 164],
#          ...,
#          [  2,  99, 227],
# ...
